# %%
import requests
import concurrent.futures
import multiprocessing
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Code to Obtain Mus Musculus Complexome Data from Complex Portal

# %%
# Get the number of CPUs available
num_cpus = multiprocessing.cpu_count()

# Define the API endpoint
# API below is to Search with a wildcard to retrieve all the information
url = 'https://www.ebi.ac.uk/intact/complex-ws/search/*'
# Make a GET request to the API
response = requests.get(url)

if response.status_code == 200:
  data = response.json()
  #filter for complexes annotated with Mus Musculus as the organism
  mouse_complexes = [element for element in data['elements'] if element['organismName']=='Mus musculus; 10090']
  #get the IDs of these complexes
  mouse_AC = [item['complexAC'] for item in mouse_complexes]
else:
  print(f"Failed to retrieve {response.status_code}")

# %%
def fetch_complex_data(mouse_complex):
    url_complex = f"https://www.ebi.ac.uk/intact/complex-ws/complex/{mouse_complex}"
    response = requests.get(url_complex)
    if response.status_code == 200:
        # Get desired info from the json stuctured data
        # participants is the key that contains a dictionary of the participating proteins in the complex
        # crossReferences key contains pubmed, GO, GCO and other such annotations about the complex
        # We are interested in the GO pathways the complex is associated with
        data = response.json()
        desired_keys = ['systematicName', 'ligands', 'complexAssemblies', 'participants']
        output = {key: data.get(key) for key in desired_keys}
        keys = ['qualifier', 'identifier', 'description'] #keys of interest in the crossReferences dictionary
        output['GO'] = [[dbi.get(key) for key in keys] for dbi in data['crossReferences'] if dbi['database'] == 'gene ontology']
        return output
    else:
        return f"Failed to retrieve {response.status_code}"

#initialize output dictionary
complex_data = {}

# Use ThreadPoolExecutor to fetch data concurrently
with concurrent.futures.ThreadPoolExecutor(max_workers=num_cpus) as executor:
    future_to_mouse_complex = {executor.submit(fetch_complex_data, mouse_complex): mouse_complex for mouse_complex in mouse_AC}
    for future in concurrent.futures.as_completed(future_to_mouse_complex):
        mouse_complex = future_to_mouse_complex[future]
        try:
            complex_data[mouse_complex] = future.result()
        except Exception as exc:
            print(f'{mouse_complex} generated an exception: {exc}')

# %%
# check the output
complex_data['CPX-679']
# Out:
# {'systematicName': 'Nr1h2:Rxra',
#  'ligands': ['9-cis-retinoic acid (CHEBI:50648)', 'oxysterol (CHEBI:53030)'],
#  'complexAssemblies': ['Heterodimer'],
#  'participants': [{'interactorAC': 'EBI-12513495',
#    'identifier': 'P28700',
#    'identifierLink': 'https://www.uniprot.org/uniprotkb/P28700/entry',
#    'name': 'Rxra',
#    'description': 'Retinoic acid receptor RXR-alpha',
#    'stochiometry': 'minValue: 1, maxValue: 1',
#    'bioRole': 'unspecified role',
#    'bioRoleMI': 'MI:0499',
#    'bioRoleDefinition': 'Role not specified or not applicable to the data.',
#    'interactorType': 'protein',
#    'interactorTypeMI': 'MI:0326',
#    'interactorTypeDefinition': 'A linear polymer of amino acids joined by peptide bonds in a specific sequence.',
#    'linkedFeatures': [{'participantId': 'Q60644',
#      'featureType': 'binding region',
#      'featureTypeMI': 'MI:0117',
#      'featureTypeDefinition': 'A region of a molecule or a component of a complex identified as being involved in an interaction. This may or may not be a region of the molecule in direct contact with the interacting partner.',
#      'ranges': ['202-446']}],
#    'otherFeatures': []},
#   {'interactorAC': 'EBI-12513491',
#    'identifier': 'Q60644',
#    'identifierLink': 'https://www.uniprot.org/uniprotkb/Q60644/entry',
#    'name': 'Nr1h2',
#    'description': 'Oxysterols receptor LXR-beta',
#    'stochiometry': 'minValue: 1, maxValue: 1',
#    'bioRole': 'unspecified role',
#    'bioRoleMI': 'MI:0499',
#    'bioRoleDefinition': 'Role not specified or not applicable to the data.',
#    'interactorType': 'protein',
#    'interactorTypeMI': 'MI:0326',
#    'interactorTypeDefinition': 'A linear polymer of amino acids joined by peptide bonds in a specific sequence.',
#    'linkedFeatures': [{'participantId': 'P28700',
#      'featureType': 'binding region',
#      'featureTypeMI': 'MI:0117',
#      'featureTypeDefinition': 'A region of a molecule or a component of a complex identified as being involved in an interaction. This may or may not be a region of the molecule in direct contact with the interacting partner.',
#      'ranges': ['230-467']}],
#    'otherFeatures': []}],
#  'GO': [['molecular function', 'GO:0001972', 'retinoic acid binding'],
#   ['molecular function', 'GO:0008142', 'oxysterol binding'],
#   ['molecular function',
#    'GO:0000981',
#    'DNA-binding transcription factor activity, RNA polymerase II-specific'],
#   ['biological process',
#    'GO:0042789',
#    'mRNA transcription from RNA polymerase II promoter'],
#   ['cellular component',
#    'GO:0090575',
#    'RNA polymerase II transcription factor complex'],
#   ['molecular function',
#    'GO:0044323',
#    'retinoic acid-responsive element binding'],
#   ['biological process',
#    'GO:0045944',
#    'positive regulation of transcription from RNA polymerase II promoter'],
#   ['biological process', 'GO:0009755', 'hormone-mediated signaling pathway']]}

# %%
len(complex_data)
# Out:
# 746

# %%
#store the output in a json file
file_path = "mus_musculus_protein_complex_compiled_data.json"
with open(file_path, "w") as outfile:
  json.dump(complex_data, outfile)

# %% [markdown]
# # Mapping Complexome to Proteome and Downstream Analysis

# %%
'''
Load in the Mouse Protein Complex JSON file created above
'''
file_path = '/content/mus_musculus_protein_complex_compiled_data.json'
with open(file_path, 'r') as f:
  data = json.load(f)

'''
Get UniProt Ids of participants in each complex
We will then use this data to see how many protein complexes are represented
  in the proteomics dataset
'''
#Get Uniprot IDs for each participant in a complex
# We have filtered for only getting the protein interactors
complex_protein_interactors = {key: [participant['identifier'] for participant in data[key]['participants'] if participant['interactorType']=='protein'] for key in list(data.keys())}

# %%
'''
Load in Proteomics Data - Ctrl & Iso for all Mouse Strains
Map the proteins in the proteomics dataset to the mouse complexome built from ComplexPortal database (above)
'''

strains = ['dba','fvb','cej','c57', 'balbc','aj']
conditions = ['iso', 'ctrl']
imputations = ['before', 'after']
pathway = '/content/'

all_data = list()
for strain in strains :
  for cond in conditions:
    for imp in imputations:
      filename = pathway + cond + "_" + strain + "_" + imp + ".csv"
      dat = pd.read_csv(filename)
      dat["cond"] = cond
      dat["strain"] = strain
      dat["imp"] = imp
      all_data.append(dat)

# Combine all dataframes in the list `all_data`
combined_data = pd.concat(all_data)

# Filter data for ISO experimental group
iso_data = combined_data[combined_data["cond"] == "iso"]

# Filter data for CTRL group
ctrl_data = combined_data[combined_data["cond"] == "ctrl"]

# %%
prots_of_interest = "P10922" , "Q3UQ17"
print([prot for prot in prots_of_interest if prot in iso_data.UniProt.unique()])
print([prot for prot in prots_of_interest if prot in ctrl_data.UniProt.unique()])
# Out:
# ['P10922']
# ['P10922']

# %%
# unique proteins in the ISO proteomics data
iso_proteome = iso_data.UniProt.unique()
print(len(iso_proteome))
# unique proteins in the CTRL proteomics data
ctrl_proteome = ctrl_data.UniProt.unique()
len(ctrl_proteome)
# Out:
# 4181
# 4011

# %% [markdown]
# ## Iso Analysis

# %%
'''
iso_complexome will contain only those complexes for which all proteins are present in iso_proteome
'''

iso_complexome = {}  # Initialize the iso_complexome dictionary

for complx, proteins in complex_protein_interactors.items():
    # Check if all proteins in the complex are represented in iso_proteome
    if all(protein in iso_proteome for protein in proteins):
        # If every single protein in the complex is present, save info to iso_complexome
        iso_complexome[complx] = {'interactors' : proteins,
                                  'assembly':''.join(data[complx]['complexAssemblies']).replace('.', '').lower(),
                                  'GO' : data[complx]['GO']}

# print(len(iso_complexome))
# with open('iso_complexome.json', 'w') as out:
#   json.dump(iso_complexome, out)

# %%
# What types of complex assemblies are present in the data
{iso['assembly'] for cpx, iso in iso_complexome.items()}
# Out:
# {'',
#  'heterodimer',
#  'heterododecamer',
#  'heterohexamer',
#  'heterononamer',
#  'heterooctamer',
#  'heterooctomer',
#  'heteropentamer',
#  'heterotetramer',
#  'heterotrimer',
#  'homodecamer',
#  'homodimer',
#  'homohexamer',
#  'homooligomer',
#  'homopentamer',
#  'homotetramer',
#  'homotrimer'}

# %%
'''
ISO Complexome Annotations
'''

complex_names = []
interactor_lists = []
assembly_list = []
go_bp_list = []
go_cc_list = []
go_mf_list = []

# Iterate over each complex
for complex_name, details in iso_complexome.items():
    # Append complex name
    complex_names.append(complex_name)
    # Join interactors into a string and append
    interactor_lists.append(', '.join(details['interactors']))
    # Append complex assembly type to list
    assembly_list.append(details['assembly'])
    # Flatten GO annotations and append
    ### Cellular Component
    go_cc = '; '.join([', '.join(go) for go in details['GO'] if go[0] == 'cellular component'])
    go_cc_list.append(go_cc)
    ### Molecular Function
    go_mf = '; '.join([', '.join(go) for go in details['GO'] if go[0] == 'molecular function'])
    go_mf_list.append(go_mf)
    ### Biological Process
    go_bp = '; '.join([', '.join(go) for go in details['GO'] if go[0] == 'biological process'])
    go_bp_list.append(go_bp)

df_iso = pd.DataFrame({
    'Complex': complex_names,
    'Assembly': assembly_list,
    'Interactors': interactor_lists,
    'GO Cellular Component': go_cc_list,
    'GO Molecular Function': go_mf_list,
    'GO Biological Process': go_bp_list
})


# Create a list of proteins by splitting the 'Interactors' column
df_iso['Interactors'] = df_iso['Interactors'].str.split(', ')

# Filter the DataFrame to include only complexes where all interactors have hetero assembly for proteins
df_hetero_complexes = df_iso[
    (df_iso['Assembly'].str.contains('hetero')) &
    (df_iso['Interactors'].apply(lambda x: len(x) > 1))
]


df_hetero_complexes
# Out:
#       Complex        Assembly               Interactors  \
# 0     CPX-689     heterodimer          [P29416, P20060]
# 4    CPX-3287  heterotetramer          [Q61081, P11499]
# 5    CPX-3289  heterotetramer          [Q61081, P07901]
# 7      CPX-16    heterotrimer  [P19123, P48787, P50752]
# 10   CPX-4301     heterodimer          [O08529, O88456]
# ..        ...             ...                       ...
# 120  CPX-3011    heterotrimer  [P02468, Q61292, Q60675]
# 121  CPX-3015    heterotrimer  [P02469, P02468, P97927]
# 122  CPX-3031    heterotrimer  [P02468, Q61292, P97927]
# 123  CPX-3016    heterotrimer  [P02469, P02468, Q61001]
# 124  CPX-3017    heterotrimer  [P02468, Q61292, Q61001]
#
#                                  GO Cellular Component  \
# 0    cellular component, GO:1905379, beta-N-acetylh...
# 4    cellular component, GO:1990565, HSP90-CDC37 ch...
# 5    cellular component, GO:1990565, HSP90-CDC37 ch...
# 7            cellular component, GO:0030017, sarcomere
# 10     cellular component, GO:0110158, calpain complex
# ..                                                 ...
# 120  cellular component, GO:0005609, laminin-4 complex
# 121  cellular component, GO:0043257, laminin-8 complex
# 122  cellular component, GO:0043258, laminin-9 complex
# 123  cellular component, GO:0043259, laminin-10 com...
# 124  cellular component, GO:0043260, laminin-11 com...
#
#                                  GO Molecular Function  \
# 0    molecular function, GO:0004563, beta-N-acetylh...
# 4    molecular function, GO:0019887, protein kinase...
# 5    molecular function, GO:0019887, protein kinase...
# 7    molecular function, GO:0005509, calcium ion bi...
# 10   molecular function, GO:0005509, calcium ion bi...
# ..                                                 ...
# 120  molecular function, GO:0005201, extracellular ...
# 121  molecular function, GO:0005201, extracellular ...
# 122  molecular function, GO:0005201, extracellular ...
# 123  molecular function, GO:0005201, extracellular ...
# 124  molecular function, GO:0005201, extracellular ...
#
#                                  GO Biological Process
# 0    biological process, GO:0030203, glycosaminogly...
# 4    biological process, GO:0032435, negative regul...
# 5    biological process, GO:0022417, protein matura...
# 7    biological process, GO:0060048, cardiac muscle...
# 10         biological process, GO:0006508, proteolysis
# ..                                                 ...
# 120  biological process, GO:0030334, regulation of ...
# 121  biological process, GO:0030334, regulation of ...
# 122  biological process, GO:0030334, regulation of ...
# 123  biological process, GO:0030334, regulation of ...
# 124  biological process, GO:0030334, regulation of ...
#
# [74 rows x 6 columns]

# %%
'''
We loop over each protein interactor
For each such protein, we select the subset of complexes where this protein is an interactor.
We then loop through these subsets and find the complex that hasn't been added yet with protein subsets that haven't been added yet
'''

# Identify interactor counts
interactor_counts = df_hetero_complexes.Interactors.explode().value_counts()
interactor_counts

# Initialize an empty DataFrame to store the unique complexes
unique_complexes_df = pd.DataFrame(columns=df_hetero_complexes.columns)

# Initialize sets to keep track of already added complexes and interactors
added_complexes = set()
added_interactors = set()

# Iterate over each interactor in the interactors_repeat Series
for interactor, count in interactor_counts.items():

    # Get the subset of df_hetero_complexes where the interactor is present
    interactor_subset = df_hetero_complexes[df_hetero_complexes['Interactors'].apply(lambda x: interactor in x)]

    # Iterate over the rows in this subset to find the first complex not already added
    for idx, row in interactor_subset.iterrows():

        if row['Complex'] not in added_complexes and not any(item in added_interactors for item in row['Interactors']):
            # Add the complex to the unique_complexes_df
            unique_complexes_df = unique_complexes_df.append(row)
            # Add the complex to the set of added complexes
            added_complexes.add(row['Complex'])
            # Add the interactors to the set of added interactors
            added_interactors.update(row['Interactors'])

all(unique_complexes_df.Interactors.explode().value_counts() == 1)
# Out:
# <ipython-input-25-96ce07b08710>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_complexes_df = unique_complexes_df.append(row)
# <ipython-input-25-96ce07b08710>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_complexes_df = unique_complexes_df.append(row)
# <ipython-input-25-96ce07b08710>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_complexes_df = unique_complexes_df.append(row)
# <ipython-input-25-96ce07b08710>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_complexes_df = unique_complexes_df.append(row)
# <ipython-input-25-96ce07b08710>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_complexes_df = unique_complexes_df.append(row)
# <ipython-input-25-96ce07b08710>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_complexes_df = unique_complexes_df.append(row)
# <ipython-input-25-96ce07b08710>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_complexes_df = unique_complexes_df.append(row)
# <ipython-input-25-96ce07b08710>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_complexes_df = unique_complexes_df.append(row)
# <ipython-input-25-96ce07b08710>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_complexes_df = unique_complexes_df.append(row)
# <ipython-input-25-96ce07b08710>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_complexes_df = unique_complexes_df.append(row)
# <ipython-input-25-96ce07b08710>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_complexes_df = unique_complexes_df.append(row)
# <ipython-input-25-96ce07b08710>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_complexes_df = unique_complexes_df.append(row)
# <ipython-input-25-96ce07b08710>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_complexes_df = unique_complexes_df.append(row)
# <ipython-input-25-96ce07b08710>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_complexes_df = unique_complexes_df.append(row)
# <ipython-input-25-96ce07b08710>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_complexes_df = unique_complexes_df.append(row)
# <ipython-input-25-96ce07b08710>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_complexes_df = unique_complexes_df.append(row)
# <ipython-input-25-96ce07b08710>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_complexes_df = unique_complexes_df.append(row)
# <ipython-input-25-96ce07b08710>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_complexes_df = unique_complexes_df.append(row)
# <ipython-input-25-96ce07b08710>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_complexes_df = unique_complexes_df.append(row)
# <ipython-input-25-96ce07b08710>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_complexes_df = unique_complexes_df.append(row)
# <ipython-input-25-96ce07b08710>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_complexes_df = unique_complexes_df.append(row)
# <ipython-input-25-96ce07b08710>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_complexes_df = unique_complexes_df.append(row)
# <ipython-input-25-96ce07b08710>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_complexes_df = unique_complexes_df.append(row)
# <ipython-input-25-96ce07b08710>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_complexes_df = unique_complexes_df.append(row)
# <ipython-input-25-96ce07b08710>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_complexes_df = unique_complexes_df.append(row)
# <ipython-input-25-96ce07b08710>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_complexes_df = unique_complexes_df.append(row)
# <ipython-input-25-96ce07b08710>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_complexes_df = unique_complexes_df.append(row)
# <ipython-input-25-96ce07b08710>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_complexes_df = unique_complexes_df.append(row)
# <ipython-input-25-96ce07b08710>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_complexes_df = unique_complexes_df.append(row)
# <ipython-input-25-96ce07b08710>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_complexes_df = unique_complexes_df.append(row)
# <ipython-input-25-96ce07b08710>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_complexes_df = unique_complexes_df.append(row)
# <ipython-input-25-96ce07b08710>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_complexes_df = unique_complexes_df.append(row)
# <ipython-input-25-96ce07b08710>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_complexes_df = unique_complexes_df.append(row)
# <ipython-input-25-96ce07b08710>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_complexes_df = unique_complexes_df.append(row)
# <ipython-input-25-96ce07b08710>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_complexes_df = unique_complexes_df.append(row)
# <ipython-input-25-96ce07b08710>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_complexes_df = unique_complexes_df.append(row)
# <ipython-input-25-96ce07b08710>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_complexes_df = unique_complexes_df.append(row)
# <ipython-input-25-96ce07b08710>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_complexes_df = unique_complexes_df.append(row)
# <ipython-input-25-96ce07b08710>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_complexes_df = unique_complexes_df.append(row)
# <ipython-input-25-96ce07b08710>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_complexes_df = unique_complexes_df.append(row)
# <ipython-input-25-96ce07b08710>:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   unique_complexes_df = unique_complexes_df.append(row)
# True

# %%
unique_complexes_df
# Out:
#       Complex         Assembly  \
# 119  CPX-3009     heterotrimer
# 53   CPX-3027      heterodimer
# 82   CPX-1054      heterodimer
# 31   CPX-5862     heterotrimer
# 23   CPX-5849     heterotrimer
# 24   CPX-5851     heterotrimer
# 48   CPX-2055   heterotetramer
# 54   CPX-3035      heterodimer
# 19   CPX-5152   heterotetramer
# 41   CPX-2185      heterodimer
# 96   CPX-2922   heterotetramer
# 78    CPX-136    heterooctomer
# 10   CPX-4301      heterodimer
# 4    CPX-3287   heterotetramer
# 17   CPX-5141   heterotetramer
# 107   CPX-670      heterodimer
# 98   CPX-3041      heterodimer
# 91   CPX-2962     heterotrimer
# 90   CPX-2959     heterotrimer
# 102   CPX-865      heterodimer
# 103   CPX-898   heterotetramer
# 108  CPX-4921     heterotrimer
# 106   CPX-616      heterodimer
# 77    CPX-133     heterotrimer
# 109  CPX-5823  heterododecamer
# 105   CPX-531      heterodimer
# 104   CPX-507      heterodimer
# 0     CPX-689      heterodimer
# 14   CPX-4622      heterodimer
# 35   CPX-5868      heterodimer
# 30   CPX-5861      heterodimer
# 15   CPX-4629    heterooctamer
# 40   CPX-2920      heterodimer
# 12   CPX-6084    heterooctamer
# 7      CPX-16     heterotrimer
# 65    CPX-377   heterotetramer
# 76    CPX-127     heterotrimer
# 73   CPX-3251     heterotrimer
# 67    CPX-562   heterotetramer
# 62   CPX-2956     heterotrimer
# 61   CPX-3129      heterodimer
#
#                                           Interactors  \
# 119                          [P02469, P02468, Q60675]
# 53                                   [P09055, P11688]
# 82                                   [P52293, P70168]
# 31                           [P10630, P63073, Q6NZJ6]
# 23                           [Q91WG5, Q9R078, Q5EG47]
# 24                           [Q8BRK8, O54950, Q6PAM0]
# 48                                   [P12382, P47857]
# 54                                   [O54890, P43406]
# 19                   [P62743, P84091, P17426, Q9DBG3]
# 41                                   [Q61239, Q8K2I1]
# 96                                   [P01942, P02088]
# 78                           [P60670, P70362, Q01853]
# 10                                   [O08529, O88456]
# 4                                    [Q61081, P11499]
# 17                   [P35585, P22892, O35643, P61967]
# 107                                  [Q8R050, Q8BWY3]
# 98                                   [Q9R1T2, Q9Z1F9]
# 91                                   [O88207, Q3U962]
# 90                                   [P02463, P08122]
# 102                                  [Q9DCW4, Q99LC5]
# 103                                  [P08207, P07356]
# 108                          [P46061, Q9ERU9, P63280]
# 106                                  [Q9CZY3, P61089]
# 77                           [Q9D1H7, P21126, Q9Z1R2]
# 109  [Q8K215, Q9Z1J3, O35943, Q9D7P6, Q9CPW2, Q9CR21]
# 105                                  [P27773, Q9R233]
# 104                                  [Q3B7Z2, Q9WV55]
# 0                                    [P29416, P20060]
# 14                                   [P47758, Q9DBG7]
# 35                                   [P11679, P05784]
# 30                                   [Q64213, P26369]
# 15                                   [Q9QZE7, Q62348]
# 40                                   [Q9JHK4, P53612]
# 12                                   [Q3URS9, Q9CXJ4]
# 7                            [P19123, P48787, P50752]
# 65                                   [P35486, Q9D051]
# 76                                   [O70548, A2ASS6]
# 73                                   [Q62432, P97471]
# 67                   [Q8K2B3, Q9CZB0, Q9CXV1, Q9CQA3]
# 62                                   [P11087, Q01149]
# 61                                   [P05555, P11835]
#
#                                  GO Cellular Component  \
# 119  cellular component, GO:0005607, laminin-2 complex
# 53   cellular component, GO:0034674, alpha5-beta1 i...
# 82   cellular component, GO:0005829, cytosol; cellu...
# 31   cellular component, GO:0016281, eukaryotic tra...
# 23   cellular component, GO:0031588, nucleotide-act...
# 24   cellular component, GO:0031588, nucleotide-act...
# 48   cellular component, GO:0005945, 6-phosphofruct...
# 54   cellular component, GO:0034683, alphav-beta3 i...
# 19   cellular component, GO:0009898, cytoplasmic si...
# 41   cellular component, GO:0005965, protein farnes...
# 96   cellular component, GO:0005833, hemoglobin com...
# 78   cellular component, GO:0034098, VCP-NPL4-UFD1 ...
# 10     cellular component, GO:0110158, calpain complex
# 4    cellular component, GO:1990565, HSP90-CDC37 ch...
# 17   cellular component, GO:0005765, lysosomal memb...
# 107  cellular component, GO:0005737, cytoplasm; cel...
# 98   cellular component, GO:0031510, SUMO activatin...
# 91   cellular component, GO:0005588, collagen type ...
# 90   cellular component, GO:0005587, collagen type ...
# 102  cellular component, GO:0005759, mitochondrial ...
# 103  cellular component, GO:0098797, plasma membran...
# 108  cellular component, GO:0005643, nuclear pore; ...
# 106  cellular component, GO:0035370, UBC13-UEV1A co...
# 77   cellular component, GO:0005829, cytosol; cellu...
# 109  cellular component, GO:1990229, iron-sulfur cl...
# 105  cellular component, GO:0061779, Tapasin-ERp57 ...
# 104  cellular component, GO:0005789, endoplasmic re...
# 0    cellular component, GO:1905379, beta-N-acetylh...
# 14   cellular component, GO:0016020, membrane; cell...
# 35    cellular component, GO:0045095, keratin filament
# 30   cellular component, GO:0089701, U2AF; cellular...
# 15   cellular component, GO:1902555, endoribonuclea...
# 40   cellular component, GO:0005968, Rab-protein ge...
# 12   cellular component, GO:0062157, mitochondrial ...
# 7            cellular component, GO:0030017, sarcomere
# 65   cellular component, GO:0045254, pyruvate dehyd...
# 76   cellular component, GO:1990733, Titin-Telethon...
# 73   cellular component, GO:0071144, heteromeric SM...
# 67   cellular component, GO:0005743, mitochondrial ...
# 62   cellular component, GO:0005584, collagen type ...
# 61   cellular component, GO:0034688, alphaM-beta2 i...
#
#                                  GO Molecular Function  \
# 119  molecular function, GO:0005201, extracellular ...
# 53   molecular function, GO:0004888, transmembrane ...
# 82   molecular function, GO:0061608, nuclear import...
# 31   molecular function, GO:0003743, translation in...
# 23   molecular function, GO:0004679, AMP-activated ...
# 24   molecular function, GO:0004679, AMP-activated ...
# 48   molecular function, GO:0003872, 6-phosphofruct...
# 54   molecular function, GO:0004888, transmembrane ...
# 19   molecular function, GO:0030276, clathrin bindi...
# 41   molecular function, GO:0004660, protein farnes...
# 96   molecular function, GO:0019825, oxygen binding...
# 78   molecular function, GO:0032553, ribonucleotide...
# 10   molecular function, GO:0005509, calcium ion bi...
# 4    molecular function, GO:0019887, protein kinase...
# 17   molecular function, GO:0030276, clathrin bindi...
# 107  molecular function, GO:0003924, GTPase activit...
# 98   molecular function, GO:0005524, ATP binding; m...
# 91   molecular function, GO:0005201, extracellular ...
# 90   molecular function, GO:0005201, extracellular ...
# 102  molecular function, GO:0009055, electron carri...
# 103  molecular function, GO:0005544, calcium-depend...
# 108  molecular function, GO:0061665, SUMO ligase ac...
# 106  molecular function, GO:0061631, ubiquitin conj...
# 77   molecular function, GO:0043022, ribosome bindi...
# 109  molecular function, GO:0004322, ferroxidase ac...
# 105  molecular function, GO:0042605, peptide antige...
# 104
# 0    molecular function, GO:0004563, beta-N-acetylh...
# 14   molecular function, GO:0003924, GTPase activit...
# 35
# 30   molecular function, GO:0030628, pre-mRNA 3'-sp...
# 15   molecular function, GO:0004521, endoribonuclea...
# 40   molecular function, GO:0008270, zinc ion bindi...
# 12   molecular function, GO:0019829, ATPase-coupled...
# 7    molecular function, GO:0005509, calcium ion bi...
# 65   molecular function, GO:0004739, pyruvate dehyd...
# 76   molecular function, GO:0051373, FATZ binding; ...
# 73   molecular function, GO:0003700, sequence-speci...
# 67   molecular function, GO:0008177, succinate dehy...
# 62   molecular function, GO:0005201, extracellular ...
# 61   molecular function, GO:0004888, transmembrane ...
#
#                                  GO Biological Process
# 119  biological process, GO:0030334, regulation of ...
# 53   biological process, GO:0007229, integrin-media...
# 82   biological process, GO:0006606, protein import...
# 31   biological process, GO:0006413, translational ...
# 23   biological process, GO:0031669, cellular respo...
# 24   biological process, GO:0031669, cellular respo...
# 48          biological process, GO:0006096, glycolysis
# 54   biological process, GO:0007229, integrin-media...
# 19   biological process, GO:0072583, clathrin-depen...
# 41   biological process, GO:0018343, protein farnes...
# 96   biological process, GO:0030185, nitric oxide t...
# 78   biological process, GO:0030970, retrograde pro...
# 10         biological process, GO:0006508, proteolysis
# 4    biological process, GO:0032435, negative regul...
# 17   biological process, GO:0016192, vesicle-mediat...
# 107  biological process, GO:0006415, translational ...
# 98
# 91   biological process, GO:0030199, collagen fibri...
# 90   biological process, GO:0030199, collagen fibri...
# 102  biological process, GO:0009063, cellular amino...
# 103  biological process, GO:1905686, positive regul...
# 108  biological process, GO:0051168, nuclear export...
# 106  biological process, GO:1902533, positive regul...
# 77   biological process, GO:0006620, posttranslatio...
# 109  biological process, GO:0016226, iron-sulfur cl...
# 105  biological process, GO:0002502, peptide antige...
# 104  biological process, GO:0035627, ceramide trans...
# 0    biological process, GO:0030203, glycosaminogly...
# 14   biological process, GO:0006617, SRP-dependent ...
# 35
# 30   biological process, GO:0000398, mRNA splicing,...
# 15   biological process, GO:0030422, production of ...
# 40
# 12   biological process, GO:0006884, cell volume ho...
# 7    biological process, GO:0060048, cardiac muscle...
# 65   biological process, GO:0006086, acetyl-CoA bio...
# 76   biological process, GO:0003009, skeletal muscl...
# 73   biological process, GO:0006351, transcription,...
# 67   biological process, GO:0006099, tricarboxylic ...
# 62   biological process, GO:0030199, collagen fibri...
# 61   biological process, GO:0007229, integrin-media...

# %%
### Proteomics Data for ISO Group ###
# Compute the log2 of median.K
iso_data = iso_data.assign(
    log2_median_K = np.log2(iso_data['median.K'])
).rename(columns={'UniProt': 'Interactors'})

# Group the data by 'UniProt' and 'imp' and calculate the mean and SEM of the turunover data for all conditions and strains before and after imputation
average_data = (
    iso_data
    .groupby(['Interactors', 'imp'])
    .agg(
        AvgTurnover=('log2_median_K', 'mean'),  # Calculate average turnover rate
        SEM=('log2_median_K', lambda x: np.std(x, ddof=1) / np.sqrt(x.count()) if x.count() > 1 else 0),  # Calculate SEM
    )
    .reset_index()
    .fillna(0)
)

# %%
# # List of desired GO annotations
# # I am interested in all of the complexes since the hetero complexes are not a lot, I will manually review the annotations for complexes where the protein interactor shows up in multiple complexes
# cellular_components_of_interest = df_hetero_complexes['GO Cellular Component']

# df_iso_interest = df_hetero_complexes[
#     df_hetero_complexes['GO Cellular Component'].apply(
#         lambda x: any(obj_type in x for obj_type in cellular_components_of_interest)
#     )
# ]

# Explode the 'Interactors' column to create a new row for each interactor
expanded_df = unique_complexes_df.explode('Interactors')

iso_complexome_turnovers = pd.merge(
    expanded_df,
    average_data,
    left_on='Interactors',
    right_on='Interactors',
    how='left'
)
iso_complexome_turnovers
# Out:
#       Complex      Assembly Interactors  \
# 0    CPX-3009  heterotrimer      P02469
# 1    CPX-3009  heterotrimer      P02469
# 2    CPX-3009  heterotrimer      P02468
# 3    CPX-3009  heterotrimer      P02468
# 4    CPX-3009  heterotrimer      Q60675
# ..        ...           ...         ...
# 183  CPX-2956  heterotrimer      Q01149
# 184  CPX-3129   heterodimer      P05555
# 185  CPX-3129   heterodimer      P05555
# 186  CPX-3129   heterodimer      P11835
# 187  CPX-3129   heterodimer      P11835
#
#                                  GO Cellular Component  \
# 0    cellular component, GO:0005607, laminin-2 complex
# 1    cellular component, GO:0005607, laminin-2 complex
# 2    cellular component, GO:0005607, laminin-2 complex
# 3    cellular component, GO:0005607, laminin-2 complex
# 4    cellular component, GO:0005607, laminin-2 complex
# ..                                                 ...
# 183  cellular component, GO:0005584, collagen type ...
# 184  cellular component, GO:0034688, alphaM-beta2 i...
# 185  cellular component, GO:0034688, alphaM-beta2 i...
# 186  cellular component, GO:0034688, alphaM-beta2 i...
# 187  cellular component, GO:0034688, alphaM-beta2 i...
#
#                                  GO Molecular Function  \
# 0    molecular function, GO:0005201, extracellular ...
# 1    molecular function, GO:0005201, extracellular ...
# 2    molecular function, GO:0005201, extracellular ...
# 3    molecular function, GO:0005201, extracellular ...
# 4    molecular function, GO:0005201, extracellular ...
# ..                                                 ...
# 183  molecular function, GO:0005201, extracellular ...
# 184  molecular function, GO:0004888, transmembrane ...
# 185  molecular function, GO:0004888, transmembrane ...
# 186  molecular function, GO:0004888, transmembrane ...
# 187  molecular function, GO:0004888, transmembrane ...
#
#                                  GO Biological Process     imp  AvgTurnover  \
# 0    biological process, GO:0030334, regulation of ...   after    -4.204458
# 1    biological process, GO:0030334, regulation of ...  before    -4.227526
# 2    biological process, GO:0030334, regulation of ...   after    -4.198551
# 3    biological process, GO:0030334, regulation of ...  before    -4.299389
# 4    biological process, GO:0030334, regulation of ...   after    -4.796800
# ..                                                 ...     ...          ...
# 183  biological process, GO:0030199, collagen fibri...  before    -4.677923
# 184  biological process, GO:0007229, integrin-media...   after    -0.407227
# 185  biological process, GO:0007229, integrin-media...  before    -0.103365
# 186  biological process, GO:0007229, integrin-media...   after    -0.278256
# 187  biological process, GO:0007229, integrin-media...  before    -1.251137
#
#           SEM
# 0    0.097913
# 1    0.084927
# 2    0.072064
# 3    0.076716
# 4    0.106358
# ..        ...
# 183  0.100245
# 184  0.000000
# 185  0.000000
# 186  1.079828
# 187  0.000000
#
# [188 rows x 9 columns]

# %%
# Sort the DataFrame to arrange the interactors grouped by complex
iso_complexome_turnovers['Interactor_ID'] = iso_complexome_turnovers.groupby(['Complex']).cumcount() + 1
iso_complexome_turnovers.sort_values(by=['Complex', 'Interactor_ID'], inplace=True)
iso_complexome_turnovers.to_csv('iso_complexome_turnovers.csv')

# %%
'''
Store combined complexome data and turnover values for ALL of the heterocomplexes represented in the proteome data
'''
# expanded_df = df_hetero_complexes.explode('Interactors')

# iso_complexome_turnovers = pd.merge(
#     expanded_df,
#     average_data,
#     left_on='Interactors',
#     right_on='Interactors',
#     how='left'
# )
# iso_complexome_turnovers

# # Sort the DataFrame to arrange the interactors grouped by complex
# iso_complexome_turnovers['Interactor_ID'] = iso_complexome_turnovers.groupby(['Complex']).cumcount() + 1
# iso_complexome_turnovers.sort_values(by=['Complex', 'Interactor_ID'], inplace=True)
# iso_complexome_turnovers.to_csv('iso_turnovers_all_heterocomplexes.csv')
# Out:
# '\nStore combined complexome data and turnover values for ALL of the heterocomplexes represented in the proteome data \n'

# %% [markdown]
# ## CTRL Analysis

# %%
ctrl_data
# Out:
#      UniProt  median.K  cond strain     imp
# 0     A2A8U2  0.101636  ctrl    dba  before
# 1     A2AAJ9  0.085461  ctrl    dba  before
# 2     A2ADF7  0.326856  ctrl    dba  before
# 3     A2AGT5  0.593946  ctrl    dba  before
# 4     A2AIL4  0.076795  ctrl    dba  before
# ...      ...       ...   ...    ...     ...
# 2604  Q9Z2W0  0.095750  ctrl     aj   after
# 2605  Q9Z2X1  0.314000  ctrl     aj   after
# 2606  Q9Z2Y3  0.325714  ctrl     aj   after
# 2607  Q9Z2Y8  0.118833  ctrl     aj   after
# 2608  Q9Z2Z6  0.038700  ctrl     aj   after
#
# [28459 rows x 5 columns]

# %%
### Proteomics Data for CTRL Group ###
# Compute the log2 of median.K
ctrl_data = ctrl_data.assign(
    log2_median_K = np.log2(ctrl_data['median.K'])
).rename(columns={'UniProt': 'Interactors'})

# Group the data by 'UniProt' and 'imp' and calculate the mean and SEM of the turunover data for all conditions and strains before and after imputation
average_data_ctrl = (
    ctrl_data
    .groupby(['Interactors', 'imp'])
    .agg(
        AvgTurnover=('log2_median_K', 'mean'),  # Calculate average turnover rate
        SEM=('log2_median_K', lambda x: np.std(x, ddof=1) / np.sqrt(x.count()) if x.count() > 1 else 0),  # Calculate SEM
    )
    .reset_index()
    .fillna(0)
)

# %%
average_data_ctrl
# Out:
#      Interactors     imp  AvgTurnover       SEM
# 0         A2A5R2   after    -1.859362  0.938346
# 1         A2A8U2   after    -2.309588  0.319581
# 2         A2A8U2  before    -2.389285  0.598205
# 3         A2A8Z1   after    -1.070499  0.526779
# 4         A2AAE1   after    -3.502914  0.076289
# ...          ...     ...          ...       ...
# 6939      Q9Z2Y8   after    -2.363193  0.644634
# 6940      Q9Z2Y8  before    -2.417988  0.652535
# 6941      Q9Z2Z6   after    -4.712402  0.054872
# 6942      Q9Z2Z6  before    -4.793228  0.070296
# 6943      Q9Z321   after    -2.498179  0.000000
#
# [6944 rows x 4 columns]

# %%
'''
ctrl_complexome will contain only those complexes for which all proteins are present in ctrl_proteome
'''

ctrl_complexome = {}  # Initialize the ctrl_complexome dictionary

for complx, proteins in complex_protein_interactors.items():
    # Check if all proteins in the complex are represented in ctrl_proteome
    if all(protein in ctrl_proteome for protein in proteins):
        # If every single protein in the complex is present, save info to ctrl_complexome
        ctrl_complexome[complx] = {'interactors' : proteins,
                                  'assembly':''.join(data[complx]['complexAssemblies']).replace('.', '').lower(),
                                  'GO' : data[complx]['GO']}


# len(ctrl_complexome)
# with open('ctrl_complexome.json', 'w') as out:
#   json.dump(ctrl_complexome, out)

# %%
# What types of complex assemblies are present in the data
{ctrl['assembly'] for cpx, ctrl in ctrl_complexome.items()}
# Out:
# {'',
#  'heterodimer',
#  'heterododecamer',
#  'heterohexamer',
#  'heterononamer',
#  'heterooctamer',
#  'heterooctomer',
#  'heteropentamer',
#  'heterotetramer',
#  'heterotrimer',
#  'homodimer',
#  'homooligomer',
#  'homopentamer',
#  'homotetramer',
#  'homotrimer'}

# %%
'''
CTRL Complexome Annotations
'''

complex_names = []
interactor_lists = []
assembly_list = []
go_bp_list = []
go_cc_list = []
go_mf_list = []

# Iterate over each complex
for complex_name, details in ctrl_complexome.items():
    # Append complex name
    complex_names.append(complex_name)
    # Join interactors into a string and append
    interactor_lists.append(', '.join(details['interactors']))
    # Append complex assembly type to list
    assembly_list.append(details['assembly'])
    # Flatten GO annotations and append
    ### Cellular Component
    go_cc = '; '.join([', '.join(go) for go in details['GO'] if go[0] == 'cellular component'])
    go_cc_list.append(go_cc)
    ### Molecular Function
    go_mf = '; '.join([', '.join(go) for go in details['GO'] if go[0] == 'molecular function'])
    go_mf_list.append(go_mf)
    ### Biological Process
    go_bp = '; '.join([', '.join(go) for go in details['GO'] if go[0] == 'biological process'])
    go_bp_list.append(go_bp)

df_ctrl = pd.DataFrame({
    'Complex': complex_names,
    'Assembly': assembly_list,
    'Interactors': interactor_lists,
    'GO Cellular Component': go_cc_list,
    'GO Molecular Function': go_mf_list,
    'GO Biological Process': go_bp_list
})


# Create a list of proteins by splitting the 'Interactors' column
df_ctrl['Interactors'] = df_ctrl['Interactors'].str.split(', ')

# Filter the DataFrame to include only complexes where all interactors have hetero assembly for proteins
df_hetero_complexes_ctrl = df_ctrl[
    (df_ctrl['Assembly'].str.contains('hetero')) &
    (df_ctrl['Interactors'].apply(lambda x: len(x) > 1))
]


df_hetero_complexes_ctrl
# Out:
#       Complex        Assembly               Interactors  \
# 0     CPX-689     heterodimer          [P29416, P20060]
# 4    CPX-3287  heterotetramer          [Q61081, P11499]
# 5    CPX-3289  heterotetramer          [Q61081, P07901]
# 6      CPX-16    heterotrimer  [P19123, P48787, P50752]
# 9    CPX-4301     heterodimer          [O08529, O88456]
# ..        ...             ...                       ...
# 109  CPX-3011    heterotrimer  [P02468, Q61292, Q60675]
# 110  CPX-3015    heterotrimer  [P02469, P02468, P97927]
# 111  CPX-3031    heterotrimer  [P02468, Q61292, P97927]
# 112  CPX-3016    heterotrimer  [P02469, P02468, Q61001]
# 113  CPX-3017    heterotrimer  [P02468, Q61292, Q61001]
#
#                                  GO Cellular Component  \
# 0    cellular component, GO:1905379, beta-N-acetylh...
# 4    cellular component, GO:1990565, HSP90-CDC37 ch...
# 5    cellular component, GO:1990565, HSP90-CDC37 ch...
# 6            cellular component, GO:0030017, sarcomere
# 9      cellular component, GO:0110158, calpain complex
# ..                                                 ...
# 109  cellular component, GO:0005609, laminin-4 complex
# 110  cellular component, GO:0043257, laminin-8 complex
# 111  cellular component, GO:0043258, laminin-9 complex
# 112  cellular component, GO:0043259, laminin-10 com...
# 113  cellular component, GO:0043260, laminin-11 com...
#
#                                  GO Molecular Function  \
# 0    molecular function, GO:0004563, beta-N-acetylh...
# 4    molecular function, GO:0019887, protein kinase...
# 5    molecular function, GO:0019887, protein kinase...
# 6    molecular function, GO:0005509, calcium ion bi...
# 9    molecular function, GO:0005509, calcium ion bi...
# ..                                                 ...
# 109  molecular function, GO:0005201, extracellular ...
# 110  molecular function, GO:0005201, extracellular ...
# 111  molecular function, GO:0005201, extracellular ...
# 112  molecular function, GO:0005201, extracellular ...
# 113  molecular function, GO:0005201, extracellular ...
#
#                                  GO Biological Process
# 0    biological process, GO:0030203, glycosaminogly...
# 4    biological process, GO:0032435, negative regul...
# 5    biological process, GO:0022417, protein matura...
# 6    biological process, GO:0060048, cardiac muscle...
# 9          biological process, GO:0006508, proteolysis
# ..                                                 ...
# 109  biological process, GO:0030334, regulation of ...
# 110  biological process, GO:0030334, regulation of ...
# 111  biological process, GO:0030334, regulation of ...
# 112  biological process, GO:0030334, regulation of ...
# 113  biological process, GO:0030334, regulation of ...
#
# [67 rows x 6 columns]

# %%
# Explode the 'Interactors' column to create a new row for each interactor
expanded_df = df_hetero_complexes_ctrl.explode('Interactors')

ctrl_complexome_turnovers = pd.merge(
    expanded_df,
    average_data_ctrl,
    left_on='Interactors',
    right_on='Interactors',
    how='left'
)

# Sort the DataFrame to arrange the interactors grouped by complex
ctrl_complexome_turnovers['Interactor_ID'] = ctrl_complexome_turnovers.groupby(['Complex']).cumcount() + 1
ctrl_complexome_turnovers.sort_values(by=['Complex', 'Interactor_ID'], inplace=True)
ctrl_complexome_turnovers.to_csv('ctrl_turnovers_all_heterocomplexes.csv')

# %%
ctrl_complexome_turnovers
# Out:
#       Complex        Assembly Interactors  \
# 183  CPX-1054     heterodimer      P52293
# 184  CPX-1054     heterodimer      P52293
# 185  CPX-1054     heterodimer      P70168
# 186  CPX-1054     heterodimer      P70168
# 187  CPX-1056     heterodimer      P70168
# ..        ...             ...         ...
# 225   CPX-865     heterodimer      Q99LC5
# 226   CPX-898  heterotetramer      P08207
# 227   CPX-898  heterotetramer      P08207
# 228   CPX-898  heterotetramer      P07356
# 229   CPX-898  heterotetramer      P07356
#
#                                  GO Cellular Component  \
# 183  cellular component, GO:0005829, cytosol; cellu...
# 184  cellular component, GO:0005829, cytosol; cellu...
# 185  cellular component, GO:0005829, cytosol; cellu...
# 186  cellular component, GO:0005829, cytosol; cellu...
# 187  cellular component, GO:0005829, cytosol; cellu...
# ..                                                 ...
# 225  cellular component, GO:0005759, mitochondrial ...
# 226  cellular component, GO:0098797, plasma membran...
# 227  cellular component, GO:0098797, plasma membran...
# 228  cellular component, GO:0098797, plasma membran...
# 229  cellular component, GO:0098797, plasma membran...
#
#                                  GO Molecular Function  \
# 183  molecular function, GO:0061608, nuclear import...
# 184  molecular function, GO:0061608, nuclear import...
# 185  molecular function, GO:0061608, nuclear import...
# 186  molecular function, GO:0061608, nuclear import...
# 187  molecular function, GO:0061608, nuclear import...
# ..                                                 ...
# 225  molecular function, GO:0009055, electron carri...
# 226  molecular function, GO:0005544, calcium-depend...
# 227  molecular function, GO:0005544, calcium-depend...
# 228  molecular function, GO:0005544, calcium-depend...
# 229  molecular function, GO:0005544, calcium-depend...
#
#                                  GO Biological Process     imp  AvgTurnover  \
# 183  biological process, GO:0006606, protein import...   after     0.240364
# 184  biological process, GO:0006606, protein import...  before    -0.171632
# 185  biological process, GO:0006606, protein import...   after    -2.739862
# 186  biological process, GO:0006606, protein import...  before    -2.734632
# 187  biological process, GO:0006606, protein import...   after    -2.739862
# ..                                                 ...     ...          ...
# 225  biological process, GO:0009063, cellular amino...  before    -4.718469
# 226  biological process, GO:1905686, positive regul...   after    -3.397634
# 227  biological process, GO:1905686, positive regul...  before    -3.549620
# 228  biological process, GO:1905686, positive regul...   after    -3.835912
# 229  biological process, GO:1905686, positive regul...  before    -3.897281
#
#           SEM  Interactor_ID
# 183  0.210608              1
# 184  0.610362              2
# 185  0.084905              3
# 186  0.078640              4
# 187  0.084905              1
# ..        ...            ...
# 225  0.038950              4
# 226  0.069720              1
# 227  0.000000              2
# 228  0.085787              3
# 229  0.087561              4
#
# [311 rows x 10 columns]

# %%
# filter df_hetero_complexes_ctrl for complexes in unique_complexes_df
df_hetero_complexes_ctrl_filtered = df_hetero_complexes_ctrl[df_hetero_complexes_ctrl['Complex'].isin(unique_complexes_df['Complex'])]
df_hetero_complexes_ctrl_filtered
# Out:
#       Complex         Assembly  \
# 0     CPX-689      heterodimer
# 4    CPX-3287   heterotetramer
# 6      CPX-16     heterotrimer
# 9    CPX-4301      heterodimer
# 11   CPX-6084    heterooctamer
# 14   CPX-4622      heterodimer
# 16   CPX-5152   heterotetramer
# 20   CPX-5851     heterotrimer
# 23   CPX-5861      heterodimer
# 24   CPX-5862     heterotrimer
# 28   CPX-5868      heterodimer
# 33   CPX-2920      heterodimer
# 34   CPX-2185      heterodimer
# 42   CPX-2055   heterotetramer
# 47   CPX-3027      heterodimer
# 48   CPX-3035      heterodimer
# 56   CPX-2956     heterotrimer
# 58    CPX-377   heterotetramer
# 60    CPX-562   heterotetramer
# 67    CPX-127     heterotrimer
# 68    CPX-133     heterotrimer
# 69    CPX-136    heterooctomer
# 71   CPX-1054      heterodimer
# 79   CPX-2959     heterotrimer
# 84   CPX-2922   heterotetramer
# 86   CPX-3041      heterodimer
# 90    CPX-865      heterodimer
# 91    CPX-898   heterotetramer
# 92    CPX-507      heterodimer
# 93    CPX-531      heterodimer
# 95    CPX-616      heterodimer
# 96    CPX-670      heterodimer
# 97   CPX-4921     heterotrimer
# 98   CPX-5823  heterododecamer
# 108  CPX-3009     heterotrimer
#
#                                           Interactors  \
# 0                                    [P29416, P20060]
# 4                                    [Q61081, P11499]
# 6                            [P19123, P48787, P50752]
# 9                                    [O08529, O88456]
# 11                                   [Q3URS9, Q9CXJ4]
# 14                                   [P47758, Q9DBG7]
# 16                   [P62743, P84091, P17426, Q9DBG3]
# 20                           [Q8BRK8, O54950, Q6PAM0]
# 23                                   [Q64213, P26369]
# 24                           [P10630, P63073, Q6NZJ6]
# 28                                   [P11679, P05784]
# 33                                   [Q9JHK4, P53612]
# 34                                   [Q61239, Q8K2I1]
# 42                                   [P12382, P47857]
# 47                                   [P09055, P11688]
# 48                                   [O54890, P43406]
# 56                                   [P11087, Q01149]
# 58                                   [P35486, Q9D051]
# 60                   [Q8K2B3, Q9CZB0, Q9CXV1, Q9CQA3]
# 67                                   [O70548, A2ASS6]
# 68                           [Q9D1H7, P21126, Q9Z1R2]
# 69                           [P60670, P70362, Q01853]
# 71                                   [P52293, P70168]
# 79                                   [P02463, P08122]
# 84                                   [P01942, P02088]
# 86                                   [Q9R1T2, Q9Z1F9]
# 90                                   [Q9DCW4, Q99LC5]
# 91                                   [P08207, P07356]
# 92                                   [Q3B7Z2, Q9WV55]
# 93                                   [P27773, Q9R233]
# 95                                   [Q9CZY3, P61089]
# 96                                   [Q8R050, Q8BWY3]
# 97                           [P46061, Q9ERU9, P63280]
# 98   [Q8K215, Q9Z1J3, O35943, Q9D7P6, Q9CPW2, Q9CR21]
# 108                          [P02469, P02468, Q60675]
#
#                                  GO Cellular Component  \
# 0    cellular component, GO:1905379, beta-N-acetylh...
# 4    cellular component, GO:1990565, HSP90-CDC37 ch...
# 6            cellular component, GO:0030017, sarcomere
# 9      cellular component, GO:0110158, calpain complex
# 11   cellular component, GO:0062157, mitochondrial ...
# 14   cellular component, GO:0016020, membrane; cell...
# 16   cellular component, GO:0009898, cytoplasmic si...
# 20   cellular component, GO:0031588, nucleotide-act...
# 23   cellular component, GO:0089701, U2AF; cellular...
# 24   cellular component, GO:0016281, eukaryotic tra...
# 28    cellular component, GO:0045095, keratin filament
# 33   cellular component, GO:0005968, Rab-protein ge...
# 34   cellular component, GO:0005965, protein farnes...
# 42   cellular component, GO:0005945, 6-phosphofruct...
# 47   cellular component, GO:0034674, alpha5-beta1 i...
# 48   cellular component, GO:0034683, alphav-beta3 i...
# 56   cellular component, GO:0005584, collagen type ...
# 58   cellular component, GO:0045254, pyruvate dehyd...
# 60   cellular component, GO:0005743, mitochondrial ...
# 67   cellular component, GO:1990733, Titin-Telethon...
# 68   cellular component, GO:0005829, cytosol; cellu...
# 69   cellular component, GO:0034098, VCP-NPL4-UFD1 ...
# 71   cellular component, GO:0005829, cytosol; cellu...
# 79   cellular component, GO:0005587, collagen type ...
# 84   cellular component, GO:0005833, hemoglobin com...
# 86   cellular component, GO:0031510, SUMO activatin...
# 90   cellular component, GO:0005759, mitochondrial ...
# 91   cellular component, GO:0098797, plasma membran...
# 92   cellular component, GO:0005789, endoplasmic re...
# 93   cellular component, GO:0061779, Tapasin-ERp57 ...
# 95   cellular component, GO:0035370, UBC13-UEV1A co...
# 96   cellular component, GO:0005737, cytoplasm; cel...
# 97   cellular component, GO:0005643, nuclear pore; ...
# 98   cellular component, GO:1990229, iron-sulfur cl...
# 108  cellular component, GO:0005607, laminin-2 complex
#
#                                  GO Molecular Function  \
# 0    molecular function, GO:0004563, beta-N-acetylh...
# 4    molecular function, GO:0019887, protein kinase...
# 6    molecular function, GO:0005509, calcium ion bi...
# 9    molecular function, GO:0005509, calcium ion bi...
# 11   molecular function, GO:0019829, ATPase-coupled...
# 14   molecular function, GO:0003924, GTPase activit...
# 16   molecular function, GO:0030276, clathrin bindi...
# 20   molecular function, GO:0004679, AMP-activated ...
# 23   molecular function, GO:0030628, pre-mRNA 3'-sp...
# 24   molecular function, GO:0003743, translation in...
# 28
# 33   molecular function, GO:0008270, zinc ion bindi...
# 34   molecular function, GO:0004660, protein farnes...
# 42   molecular function, GO:0003872, 6-phosphofruct...
# 47   molecular function, GO:0004888, transmembrane ...
# 48   molecular function, GO:0004888, transmembrane ...
# 56   molecular function, GO:0005201, extracellular ...
# 58   molecular function, GO:0004739, pyruvate dehyd...
# 60   molecular function, GO:0008177, succinate dehy...
# 67   molecular function, GO:0051373, FATZ binding; ...
# 68   molecular function, GO:0043022, ribosome bindi...
# 69   molecular function, GO:0032553, ribonucleotide...
# 71   molecular function, GO:0061608, nuclear import...
# 79   molecular function, GO:0005201, extracellular ...
# 84   molecular function, GO:0019825, oxygen binding...
# 86   molecular function, GO:0005524, ATP binding; m...
# 90   molecular function, GO:0009055, electron carri...
# 91   molecular function, GO:0005544, calcium-depend...
# 92
# 93   molecular function, GO:0042605, peptide antige...
# 95   molecular function, GO:0061631, ubiquitin conj...
# 96   molecular function, GO:0003924, GTPase activit...
# 97   molecular function, GO:0061665, SUMO ligase ac...
# 98   molecular function, GO:0004322, ferroxidase ac...
# 108  molecular function, GO:0005201, extracellular ...
#
#                                  GO Biological Process
# 0    biological process, GO:0030203, glycosaminogly...
# 4    biological process, GO:0032435, negative regul...
# 6    biological process, GO:0060048, cardiac muscle...
# 9          biological process, GO:0006508, proteolysis
# 11   biological process, GO:0006884, cell volume ho...
# 14   biological process, GO:0006617, SRP-dependent ...
# 16   biological process, GO:0072583, clathrin-depen...
# 20   biological process, GO:0031669, cellular respo...
# 23   biological process, GO:0000398, mRNA splicing,...
# 24   biological process, GO:0006413, translational ...
# 28
# 33
# 34   biological process, GO:0018343, protein farnes...
# 42          biological process, GO:0006096, glycolysis
# 47   biological process, GO:0007229, integrin-media...
# 48   biological process, GO:0007229, integrin-media...
# 56   biological process, GO:0030199, collagen fibri...
# 58   biological process, GO:0006086, acetyl-CoA bio...
# 60   biological process, GO:0006099, tricarboxylic ...
# 67   biological process, GO:0003009, skeletal muscl...
# 68   biological process, GO:0006620, posttranslatio...
# 69   biological process, GO:0030970, retrograde pro...
# 71   biological process, GO:0006606, protein import...
# 79   biological process, GO:0030199, collagen fibri...
# 84   biological process, GO:0030185, nitric oxide t...
# 86
# 90   biological process, GO:0009063, cellular amino...
# 91   biological process, GO:1905686, positive regul...
# 92   biological process, GO:0035627, ceramide trans...
# 93   biological process, GO:0002502, peptide antige...
# 95   biological process, GO:1902533, positive regul...
# 96   biological process, GO:0006415, translational ...
# 97   biological process, GO:0051168, nuclear export...
# 98   biological process, GO:0016226, iron-sulfur cl...
# 108  biological process, GO:0030334, regulation of ...

# %%
# Do df_hetero_complexes_ctrl_filtered.Complex and unique_complexes_df.Complex have all the same complexes?

unique_complexes_df[unique_complexes_df.Complex.isin(df_hetero_complexes_ctrl_filtered.Complex) == False]
# Out:
#      Complex        Assembly                       Interactors  \
# 23  CPX-5849    heterotrimer          [Q91WG5, Q9R078, Q5EG47]
# 17  CPX-5141  heterotetramer  [P35585, P22892, O35643, P61967]
# 91  CPX-2962    heterotrimer                  [O88207, Q3U962]
# 15  CPX-4629   heterooctamer                  [Q9QZE7, Q62348]
# 73  CPX-3251    heterotrimer                  [Q62432, P97471]
# 61  CPX-3129     heterodimer                  [P05555, P11835]
#
#                                 GO Cellular Component  \
# 23  cellular component, GO:0031588, nucleotide-act...
# 17  cellular component, GO:0005765, lysosomal memb...
# 91  cellular component, GO:0005588, collagen type ...
# 15  cellular component, GO:1902555, endoribonuclea...
# 73  cellular component, GO:0071144, heteromeric SM...
# 61  cellular component, GO:0034688, alphaM-beta2 i...
#
#                                 GO Molecular Function  \
# 23  molecular function, GO:0004679, AMP-activated ...
# 17  molecular function, GO:0030276, clathrin bindi...
# 91  molecular function, GO:0005201, extracellular ...
# 15  molecular function, GO:0004521, endoribonuclea...
# 73  molecular function, GO:0003700, sequence-speci...
# 61  molecular function, GO:0004888, transmembrane ...
#
#                                 GO Biological Process
# 23  biological process, GO:0031669, cellular respo...
# 17  biological process, GO:0016192, vesicle-mediat...
# 91  biological process, GO:0030199, collagen fibri...
# 15  biological process, GO:0030422, production of ...
# 73  biological process, GO:0006351, transcription,...
# 61  biological process, GO:0007229, integrin-media...

# %%
len(df_hetero_complexes_ctrl_filtered)
# Out:
# 35

# %%
# Explode the 'Interactors' column to create a new row for each interactor
expanded_df = df_hetero_complexes_ctrl_filtered.explode('Interactors')

ctrl_complexome_turnovers_filtered = pd.merge(
    expanded_df,
    average_data_ctrl,
    left_on='Interactors',
    right_on='Interactors',
    how='left'
)

# Sort the DataFrame to arrange the interactors grouped by complex
ctrl_complexome_turnovers_filtered['Interactor_ID'] = ctrl_complexome_turnovers_filtered.groupby(['Complex']).cumcount() + 1
ctrl_complexome_turnovers_filtered.sort_values(by=['Complex', 'Interactor_ID'], inplace=True)
ctrl_complexome_turnovers_filtered.to_csv('ctrl_turnovers_for_heterocomplexes_shared_with_iso.csv')
